# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# Store filepath in a variable
election_data = "president_county_candidate(11162020).csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
election_data_df = pd.read_csv(election_data, encoding="utf-8")

# %%
# Show just the header
election_data_df.head(25)
# Out:
#                    state                county       candidate party  \
# 0               Delaware           Kent County       Joe Biden   DEM
# 1               Delaware           Kent County    Donald Trump   REP
# 2               Delaware           Kent County    Jo Jorgensen   LIB
# 3               Delaware           Kent County   Howie Hawkins   GRN
# 4               Delaware     New Castle County       Joe Biden   DEM
# 5               Delaware     New Castle County    Donald Trump   REP
# 6               Delaware     New Castle County    Jo Jorgensen   LIB
# 7               Delaware     New Castle County   Howie Hawkins   GRN
# 8               Delaware         Sussex County    Donald Trump   REP
# 9               Delaware         Sussex County       Joe Biden   DEM
# 10              Delaware         Sussex County    Jo Jorgensen   LIB
# 11              Delaware         Sussex County   Howie Hawkins   GRN
# 12  District of Columbia  District of Columbia       Joe Biden   DEM
# ...

# %%
election_data_df['id'] = election_data_df.index
election_data_df= election_data_df.rename(columns = {'total_votes':'county_votes'})
election_data_df.head(25)
# Out:
#                    state                county       candidate party  \
# 0               Delaware           Kent County       Joe Biden   DEM
# 1               Delaware           Kent County    Donald Trump   REP
# 2               Delaware           Kent County    Jo Jorgensen   LIB
# 3               Delaware           Kent County   Howie Hawkins   GRN
# 4               Delaware     New Castle County       Joe Biden   DEM
# 5               Delaware     New Castle County    Donald Trump   REP
# 6               Delaware     New Castle County    Jo Jorgensen   LIB
# 7               Delaware     New Castle County   Howie Hawkins   GRN
# 8               Delaware         Sussex County    Donald Trump   REP
# 9               Delaware         Sussex County       Joe Biden   DEM
# 10              Delaware         Sussex County    Jo Jorgensen   LIB
# 11              Delaware         Sussex County   Howie Hawkins   GRN
# 12  District of Columbia  District of Columbia       Joe Biden   DEM
# ...

# %%
election_data_df.set_index('id', inplace = True)

# %%
election_data_df.head()
# Out:
#        state             county      candidate party  county_votes    won
# id
# 0   Delaware        Kent County      Joe Biden   DEM         44552   True
# 1   Delaware        Kent County   Donald Trump   REP         41009  False
# 2   Delaware        Kent County   Jo Jorgensen   LIB          1044  False
# 3   Delaware        Kent County  Howie Hawkins   GRN           420  False
# 4   Delaware  New Castle County      Joe Biden   DEM        195034   True

# %%
# Store filepath in a variable
population_data = "estimated_2019population.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
population_data_df = pd.read_csv(population_data, encoding="utf-8")

# %%
# Show just the header
population_data_df.head()
# Out:
#         state  est_population
# 0     Alabama         4903185
# 1      Alaska          731545
# 2     Arizona         7278717
# 3    Arkansas         3017804
# 4  California        39512223

# %%
population_data_df['id'] = population_data_df.index
population_data_df.set_index('id', inplace = True)

# %%
population_data_df.head()
# Out:
#          state  est_population
# id
# 0      Alabama         4903185
# 1       Alaska          731545
# 2      Arizona         7278717
# 3     Arkansas         3017804
# 4   California        39512223

# %%
#Loading csv containing all total number of votes form every state of the 2020 election data 
csv_file = "president_state.csv"
statevotemap = pd.read_csv(csv_file, encoding='ISO-8859-1')
statevotemap.head()
# Out:
#                   state  total_votes
# 0              Delaware       504010
# 1  District of Columbia       333682
# 2               Florida     11067083
# 3               Georgia      4992772
# 4                Hawaii       574341

# %%
#Esport index reset 
statevotemap = statevotemap.reset_index()
statevotemap= statevotemap.rename(columns = {'total_votes':'state_votes'})
statevotemap.head()
# Out:
#    index                 state  state_votes
# 0      0              Delaware       504010
# 1      1  District of Columbia       333682
# 2      2               Florida     11067083
# 3      3               Georgia      4992772
# 4      4                Hawaii       574341

# %%
#Setting Index to its own column
statevotemap = statevotemap.rename(columns = {'index':'id'})
statevotemap.set_index('id', inplace = True)
statevotemap.head()
# Out:
#                    state  state_votes
# id
# 0               Delaware       504010
# 1   District of Columbia       333682
# 2                Florida     11067083
# 3                Georgia      4992772
# 4                 Hawaii       574341

# %%
#Impoting data 2 
csv_file2 = "Electoral_College.csv"
electoralcollege = pd.read_csv(csv_file2, encoding='ISO-8859-1')
#ELECTORAL COLLEGE VOTE FROM 2020 
electoralcollege = electoralcollege[electoralcollege['year'] == 2020]
electoralcollege.head()
# Out:
#      year       state  votes
# 58   2020     Alabama    9.0
# 117  2020      Alaska    3.0
# 176  2020     Arizona   11.0
# 235  2020    Arkansas    6.0
# 294  2020  California   55.0

# %%
electoralcollege = electoralcollege .reset_index()
electoralcollege.head()
# Out:
#    index  year       state  votes
# 0     58  2020     Alabama    9.0
# 1    117  2020      Alaska    3.0
# 2    176  2020     Arizona   11.0
# 3    235  2020    Arkansas    6.0
# 4    294  2020  California   55.0

# %%
electoralcollege = electoralcollege.drop(columns = {'index'})
electoralcollege.head()
# Out:
#    year       state  votes
# 0  2020     Alabama    9.0
# 1  2020      Alaska    3.0
# 2  2020     Arizona   11.0
# 3  2020    Arkansas    6.0
# 4  2020  California   55.0

# %%
electoralcollege['id']= electoralcollege.index
electoralcollege
# Out:
#     year           state  votes  id
# 0   2020         Alabama    9.0   0
# 1   2020          Alaska    3.0   1
# 2   2020         Arizona   11.0   2
# 3   2020        Arkansas    6.0   3
# 4   2020      California   55.0   4
# 5   2020        Colorado    9.0   5
# 6   2020     Connecticut    7.0   6
# 7   2020            D.C.    3.0   7
# 8   2020        Delaware    3.0   8
# 9   2020         Florida   29.0   9
# 10  2020         Georgia   16.0  10
# 11  2020          Hawaii    4.0  11
# 12  2020           Idaho    4.0  12
# 13  2020        Illinois   20.0  13
# 14  2020         Indiana   11.0  14
# 15  2020            Iowa    6.0  15
# 16  2020          Kansas    6.0  16
# 17  2020        Kentucky    8.0  17
# 18  2020       Louisiana    8.0  18
# 19  2020           Maine    4.0  19
# 20  2020        Maryland   10.0  20
# 21  2020   Massachusetts   11.0  21
# 22  2020        Michigan   16.0  22
# 23  2020       Minnesota   10.0  23
# 24  2020     Mississippi    6.0  24
# ...

# %%
electoralcollege.set_index('id', inplace = True)

# %%
electoralcollege.head()
# Out:
#     year       state  votes
# id
# 0   2020     Alabama    9.0
# 1   2020      Alaska    3.0
# 2   2020     Arizona   11.0
# 3   2020    Arkansas    6.0
# 4   2020  California   55.0

# %%
electoralcollege = electoralcollege.rename(columns= {'votes':'electoral_votes'})
electoralcollege.head()
# Out:
#     year       state  electoral_votes
# id
# 0   2020     Alabama              9.0
# 1   2020      Alaska              3.0
# 2   2020     Arizona             11.0
# 3   2020    Arkansas              6.0
# 4   2020  California             55.0

# %%
rds_connection_string = "postgres:Blue14horse@localhost:5432/election2020"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['electoral_college',
#  'state_votes',
#  'state_population',
#  'county_votes',
#  'election2020_votes']

# %%
electoralcollege.to_sql(name = 'electoral_college', con = engine, if_exists = 'append', index = True)

# %%
statevotemap.to_sql(name = 'state_votes', con = engine, if_exists = 'append', index = True)

# %%
population_data_df.to_sql(name = 'state_population', con = engine, if_exists = 'append', index = True)

# %%
election_data_df.to_sql(name = 'county_votes', con = engine, if_exists = 'append', index = True)

# %%
election2020_final = pd.read_sql('select * from election2020_final' ,conn)

# %%
election2020_final.head()
# Out:
#    id       state  est_population  state_votes  electoral_votes
# 0   0     Alabama         4903185      2309900              9.0
# 1   1      Alaska          731545       349473              3.0
# 2   2     Arizona         7278717      3385845             11.0
# 3   3    Arkansas         3017804      1212065              6.0
# 4   4  California        39512223     16909159             55.0

# %%
election2020_final = election2020_final.drop(columns = ['id'])

# %%
election2020_final.head()
# Out:
#         state  est_population  state_votes  electoral_votes
# 0     Alabama         4903185      2309900              9.0
# 1      Alaska          731545       349473              3.0
# 2     Arizona         7278717      3385845             11.0
# 3    Arkansas         3017804      1212065              6.0
# 4  California        39512223     16909159             55.0

# %%
election2020_final["state_percentage"] = election2020_final["state_votes"] / election2020_final["est_population"] * 100

# %%
election2020_final.head()
# Out:
#         state  est_population  state_votes  electoral_votes  state_percentage
# 0     Alabama         4903185      2309900              9.0         47.110195
# 1      Alaska          731545       349473              3.0         47.771907
# 2     Arizona         7278717      3385845             11.0         46.517058
# 3    Arkansas         3017804      1212065              6.0         40.163808
# 4  California        39512223     16909159             55.0         42.794755

# %%
# Export file as a CSV, without the Pandas index, but with the header
election2020_final.to_csv("election2020_final.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
election_data_df.to_csv("county_votes2020.csv", index=False, header=True)
